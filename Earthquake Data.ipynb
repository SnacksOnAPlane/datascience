# %%
# %matplotlib inline
import pandas as pd
data = pd.read_table("earthquake_data/all.catalog", sep='\s+', comment='#')
mags = data['MAG']
mags.hist(bins=20)
data
# Out:
#          YYY  MM  DD     HH  mm  SS.ss  LATITUDE  LONGITUDE  Q  MAG     DEPTH  \
# 1932 1     1  23  52   7.87  34   7.80      -117      59.58  D  0.0   6.00000
#      1     2  16  42  43.68  33  54.15      -117      38.70  C  2.7   6.00000
#      1     3  17  58  10.01  32   0.00      -116       0.00  D  3.0   6.00000
#      1     4  21  30   0.96  33  46.27      -117      29.65  C  2.0   6.00000
#      1     5   2  37  27.96  33  33.57      -118      26.50  C  1.5   6.00000
#      1     6   8   8  38.62  34   8.60      -117      28.49  C  2.0   6.00000
#      1     7   2  29  22.37  33  59.51      -118      11.64  C  1.0   6.00000
#      1     7   5  39  23.73  34   5.65      -117      15.81  C  1.0   6.00000
#      1     7  14  55  43.92  32   0.00      -116       0.00  D  3.0   6.00000
#      1     7  21  25  55.85  34  46.47      -118      48.86  D  2.0   6.00000
#      1    10  10  44  54.53  33  51.41      -117      32.22  C  3.1   6.00000
# ...
